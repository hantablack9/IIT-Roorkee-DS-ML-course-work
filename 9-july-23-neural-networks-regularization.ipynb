# %% [markdown]
# # Regularization

# %% [markdown]
# Overfitting, also known as High Variance, occurs when a model learns the training data too well but fail to generalize to new data.

# %% [markdown]
# ## Regularization Techniques

# %% [markdown]
# #### Regularization refers to a set of different techniques that lower the complexity of a neural network model during training, and thus minimize/prevent the overfitting.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Importing the useful files

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
iris = load_iris()
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %% [markdown]
# ## Exploring data

# %%
# Load data into a DataFrame
df = pd.DataFrame(iris.data, columns=iris.feature_names)
# Convert datatype to float
df = df.astype(float)
# append "target" and name it "label"
df['label'] = iris.target
# Use string label instead
df['label'] = df.label.replace(dict(enumerate(iris.target_names)))

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#     label
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# ### Preparing data for Keras and TensorFlow

# %%
# label -> one-hot encoding
label = pd.get_dummies(df['label'], prefix='label')
df = pd.concat([df, label], axis=1)
# drop old label
df.drop(['label'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    label_setosa  label_versicolor  label_virginica
# 0             1                 0                0
# 1             1                 0                0
# 2             1                 0                0
# 3             1                 0                0
# 4             1                 0                0

# %%
# Creating X and y

X = df[['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']]
# Convert DataFrame into np array
X = np.asarray(X)

y = df[['label_setosa', 'label_versicolor', 'label_virginica']]
# Convert DataFrame into np array
y = np.asarray(y)

# %%
# Split the data set in a training set (80%) and a test set (20%)
X_train, X_test, y_train, y_test = train_test_split(
  X,
  y,
  test_size=0.20
)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (120, 4)
# (30, 4)
# (120, 3)
# (30, 3)

# %% [markdown]
# ## 1. Build an unregularized neural network model

# %% [markdown]
# 1. Build an unregularized neural network model
#
# Before applying regularization, let’s build a neural network without regularization and take a look at the overfitting issue.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

## def create_model(): 
model = Sequential([
        Dense(64, activation='relu', input_shape=(4,)),
        Dense(128, activation='relu'),
        Dense(128, activation='relu'),
        Dense(128, activation='relu'),
        Dense(64, activation='relu'),
        Dense(64, activation='relu'),
        Dense(64, activation='relu'),
        Dense(3, activation='softmax'),
    ])
    ## return model

# %% [markdown]
#     The first layer (also known as the input layer) has the input_shape to set the input size (4,)
#     The input layer has 64 units, followed by 3 dense layers, each with 128 units.
#     Then there are further 3 dense layers, each with 64 units.
#     All these layers use the ReLU activation function.
#     The output Dense layer has 3 units and the softmax activation function.

# %%
##model = model_1
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                320
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 64)                4160
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dense_7 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 58,435
# Trainable params: 58,435
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 1.1 Training a model
#
# In order to train a model, we first have to configure our model using compile() and pass the following arguments:
#
#     Use Adam (adam) optimization algorithm as the optimizer
#     Use categorical cross-entropy loss function (categorical_crossentropy) for our multiple-class classification problem
#     For simplicity, use accuracy as our evaluation metrics to evaluate the model during training and testing.

# %% [markdown]
# ### Compile the model

# %%
model.compile(
    optimizer='adam', 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
)

# %% [markdown]
# ### Fit the model to the training data

# %%
history = model.fit(
    X_train, 
    y_train, 
    epochs=200, 
    validation_split=0.25, 
    batch_size=40, 
    verbose=2
)
# Out:
# Epoch 1/200
# 3/3 - 2s - loss: 1.0641 - accuracy: 0.4111 - val_loss: 1.0610 - val_accuracy: 0.3000 - 2s/epoch - 709ms/step
# Epoch 2/200
# 3/3 - 0s - loss: 0.9852 - accuracy: 0.4111 - val_loss: 1.0273 - val_accuracy: 0.3000 - 60ms/epoch - 20ms/step
# Epoch 3/200
# 3/3 - 0s - loss: 0.9083 - accuracy: 0.4222 - val_loss: 0.9520 - val_accuracy: 0.6000 - 47ms/epoch - 16ms/step
# Epoch 4/200
# 3/3 - 0s - loss: 0.8257 - accuracy: 0.7222 - val_loss: 0.8716 - val_accuracy: 0.6000 - 48ms/epoch - 16ms/step
# Epoch 5/200
# 3/3 - 0s - loss: 0.7275 - accuracy: 0.7222 - val_loss: 0.7627 - val_accuracy: 0.6000 - 42ms/epoch - 14ms/step
# Epoch 6/200
# 3/3 - 0s - loss: 0.6170 - accuracy: 0.7222 - val_loss: 0.6305 - val_accuracy: 0.6000 - 45ms/epoch - 15ms/step
# Epoch 7/200
# 3/3 - 0s - loss: 0.5215 - accuracy: 0.7222 - val_loss: 0.5226 - val_accuracy: 0.6000 - 46ms/epoch - 15ms/step
# Epoch 8/200
# 3/3 - 0s - loss: 0.4168 - accuracy: 0.7667 - val_loss: 0.4028 - val_accuracy: 0.8667 - 46ms/epoch - 15ms/step
# Epoch 9/200
# 3/3 - 0s - loss: 0.3386 - accuracy: 0.9000 - val_loss: 0.3164 - val_accuracy: 0.9667 - 42ms/epoch - 14ms/step
# Epoch 10/200
# 3/3 - 0s - loss: 0.3023 - accuracy: 0.9556 - val_loss: 0.2721 - val_accuracy: 0.8667 - 46ms/epoch - 15ms/step
# Epoch 11/200
# 3/3 - 0s - loss: 0.2257 - accuracy: 0.9778 - val_loss: 0.2497 - val_accuracy: 0.8667 - 57ms/epoch - 19ms/step
# Epoch 12/200
# 3/3 - 0s - loss: 0.1906 - accuracy: 0.9667 - val_loss: 0.1749 - val_accuracy: 0.9667 - 54ms/epoch - 18ms/step
# Epoch 13/200
# 3/3 - 0s - loss: 0.1551 - accuracy: 0.9778 - val_loss: 0.1997 - val_accuracy: 0.8667 - 47ms/epoch - 16ms/step
# Epoch 14/200
# 3/3 - 0s - loss: 0.1734 - accuracy: 0.9333 - val_loss: 0.2718 - val_accuracy: 0.8667 - 47ms/epoch - 16ms/step
# Epoch 15/200
# 3/3 - 0s - loss: 0.1562 - accuracy: 0.9444 - val_loss: 0.1576 - val_accuracy: 0.9333 - 44ms/epoch - 15ms/step
# Epoch 16/200
# 3/3 - 0s - loss: 0.1400 - accuracy: 0.9556 - val_loss: 0.0920 - val_accuracy: 1.0000 - 43ms/epoch - 14ms/step
# Epoch 17/200
# 3/3 - 0s - loss: 0.1226 - accuracy: 0.9222 - val_loss: 0.1782 - val_accuracy: 0.9000 - 46ms/epoch - 15ms/step
# Epoch 18/200
# 3/3 - 0s - loss: 0.1011 - accuracy: 0.9667 - val_loss: 0.0805 - val_accuracy: 0.9667 - 47ms/epoch - 16ms/step
# Epoch 19/200
# 3/3 - 0s - loss: 0.0860 - accuracy: 0.9889 - val_loss: 0.2982 - val_accuracy: 0.8667 - 45ms/epoch - 15ms/step
# Epoch 20/200
# 3/3 - 0s - loss: 0.1441 - accuracy: 0.9333 - val_loss: 0.0629 - val_accuracy: 0.9667 - 48ms/epoch - 16ms/step
# Epoch 21/200
# 3/3 - 0s - loss: 0.1152 - accuracy: 0.9667 - val_loss: 0.0804 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 22/200
# 3/3 - 0s - loss: 0.0909 - accuracy: 0.9778 - val_loss: 0.1504 - val_accuracy: 0.9333 - 43ms/epoch - 14ms/step
# Epoch 23/200
# 3/3 - 0s - loss: 0.0876 - accuracy: 0.9889 - val_loss: 0.1816 - val_accuracy: 0.9000 - 61ms/epoch - 20ms/step
# Epoch 24/200
# 3/3 - 0s - loss: 0.0896 - accuracy: 0.9889 - val_loss: 0.0964 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 25/200
# 3/3 - 0s - loss: 0.0878 - accuracy: 0.9889 - val_loss: 0.1830 - val_accuracy: 0.9000 - 47ms/epoch - 16ms/step
# Epoch 26/200
# 3/3 - 0s - loss: 0.0888 - accuracy: 0.9667 - val_loss: 0.0557 - val_accuracy: 0.9667 - 48ms/epoch - 16ms/step
# Epoch 27/200
# 3/3 - 0s - loss: 0.0819 - accuracy: 0.9778 - val_loss: 0.2550 - val_accuracy: 0.8667 - 48ms/epoch - 16ms/step
# Epoch 28/200
# 3/3 - 0s - loss: 0.1064 - accuracy: 0.9556 - val_loss: 0.0519 - val_accuracy: 1.0000 - 41ms/epoch - 14ms/step
# Epoch 29/200
# 3/3 - 0s - loss: 0.0977 - accuracy: 0.9556 - val_loss: 0.2921 - val_accuracy: 0.8667 - 48ms/epoch - 16ms/step
# Epoch 30/200
# 3/3 - 0s - loss: 0.1542 - accuracy: 0.9556 - val_loss: 0.0568 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 31/200
# 3/3 - 0s - loss: 0.1137 - accuracy: 0.9333 - val_loss: 0.3449 - val_accuracy: 0.8667 - 41ms/epoch - 14ms/step
# Epoch 32/200
# 3/3 - 0s - loss: 0.2835 - accuracy: 0.8778 - val_loss: 0.1939 - val_accuracy: 0.9000 - 50ms/epoch - 17ms/step
# Epoch 33/200
# 3/3 - 0s - loss: 0.2280 - accuracy: 0.9111 - val_loss: 0.1025 - val_accuracy: 0.9667 - 49ms/epoch - 16ms/step
# Epoch 34/200
# 3/3 - 0s - loss: 0.3182 - accuracy: 0.9000 - val_loss: 0.7638 - val_accuracy: 0.7000 - 48ms/epoch - 16ms/step
# Epoch 35/200
# 3/3 - 0s - loss: 0.3334 - accuracy: 0.8444 - val_loss: 0.1004 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 36/200
# 3/3 - 0s - loss: 0.1672 - accuracy: 0.9222 - val_loss: 0.1806 - val_accuracy: 0.8667 - 44ms/epoch - 15ms/step
# Epoch 37/200
# 3/3 - 0s - loss: 0.2249 - accuracy: 0.9111 - val_loss: 0.1435 - val_accuracy: 0.9333 - 44ms/epoch - 15ms/step
# Epoch 38/200
# 3/3 - 0s - loss: 0.1268 - accuracy: 0.9556 - val_loss: 0.3546 - val_accuracy: 0.8333 - 45ms/epoch - 15ms/step
# Epoch 39/200
# 3/3 - 0s - loss: 0.1921 - accuracy: 0.8889 - val_loss: 0.2174 - val_accuracy: 0.8667 - 42ms/epoch - 14ms/step
# Epoch 40/200
# 3/3 - 0s - loss: 0.1107 - accuracy: 0.9778 - val_loss: 0.1058 - val_accuracy: 0.9667 - 40ms/epoch - 13ms/step
# Epoch 41/200
# 3/3 - 0s - loss: 0.1013 - accuracy: 0.9889 - val_loss: 0.0903 - val_accuracy: 1.0000 - 40ms/epoch - 13ms/step
# Epoch 42/200
# 3/3 - 0s - loss: 0.1190 - accuracy: 0.9556 - val_loss: 0.0925 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 43/200
# 3/3 - 0s - loss: 0.0890 - accuracy: 0.9889 - val_loss: 0.1624 - val_accuracy: 0.9000 - 43ms/epoch - 14ms/step
# Epoch 44/200
# 3/3 - 0s - loss: 0.0933 - accuracy: 0.9778 - val_loss: 0.1621 - val_accuracy: 0.9000 - 39ms/epoch - 13ms/step
# Epoch 45/200
# 3/3 - 0s - loss: 0.0872 - accuracy: 0.9889 - val_loss: 0.1083 - val_accuracy: 0.9667 - 47ms/epoch - 16ms/step
# Epoch 46/200
# 3/3 - 0s - loss: 0.0789 - accuracy: 0.9889 - val_loss: 0.0739 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 47/200
# 3/3 - 0s - loss: 0.0817 - accuracy: 0.9889 - val_loss: 0.0875 - val_accuracy: 0.9667 - 46ms/epoch - 15ms/step
# Epoch 48/200
# 3/3 - 0s - loss: 0.0702 - accuracy: 0.9889 - val_loss: 0.1427 - val_accuracy: 0.9333 - 42ms/epoch - 14ms/step
# Epoch 49/200
# 3/3 - 0s - loss: 0.0851 - accuracy: 0.9778 - val_loss: 0.1566 - val_accuracy: 0.9000 - 42ms/epoch - 14ms/step
# Epoch 50/200
# 3/3 - 0s - loss: 0.0759 - accuracy: 0.9889 - val_loss: 0.0777 - val_accuracy: 0.9667 - 48ms/epoch - 16ms/step
# Epoch 51/200
# 3/3 - 0s - loss: 0.0777 - accuracy: 0.9889 - val_loss: 0.0664 - val_accuracy: 0.9667 - 38ms/epoch - 13ms/step
# Epoch 52/200
# 3/3 - 0s - loss: 0.0774 - accuracy: 0.9889 - val_loss: 0.1381 - val_accuracy: 0.9333 - 42ms/epoch - 14ms/step
# Epoch 53/200
# 3/3 - 0s - loss: 0.0701 - accuracy: 0.9889 - val_loss: 0.0871 - val_accuracy: 0.9667 - 49ms/epoch - 16ms/step
# Epoch 54/200
# 3/3 - 0s - loss: 0.0758 - accuracy: 0.9889 - val_loss: 0.0546 - val_accuracy: 0.9667 - 42ms/epoch - 14ms/step
# Epoch 55/200
# 3/3 - 0s - loss: 0.0759 - accuracy: 0.9889 - val_loss: 0.0956 - val_accuracy: 0.9667 - 58ms/epoch - 19ms/step
# Epoch 56/200
# 3/3 - 0s - loss: 0.0627 - accuracy: 0.9889 - val_loss: 0.0812 - val_accuracy: 0.9667 - 40ms/epoch - 13ms/step
# Epoch 57/200
# 3/3 - 0s - loss: 0.0621 - accuracy: 0.9889 - val_loss: 0.0578 - val_accuracy: 0.9667 - 46ms/epoch - 15ms/step
# Epoch 58/200
# 3/3 - 0s - loss: 0.0711 - accuracy: 0.9889 - val_loss: 0.0614 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 59/200
# 3/3 - 0s - loss: 0.0683 - accuracy: 0.9889 - val_loss: 0.0965 - val_accuracy: 0.9667 - 40ms/epoch - 13ms/step
# Epoch 60/200
# 3/3 - 0s - loss: 0.0665 - accuracy: 0.9889 - val_loss: 0.1105 - val_accuracy: 0.9333 - 45ms/epoch - 15ms/step
# Epoch 61/200
# 3/3 - 0s - loss: 0.0649 - accuracy: 0.9889 - val_loss: 0.0762 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 62/200
# 3/3 - 0s - loss: 0.0635 - accuracy: 0.9889 - val_loss: 0.0898 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 63/200
# 3/3 - 0s - loss: 0.0603 - accuracy: 0.9889 - val_loss: 0.0946 - val_accuracy: 0.9667 - 42ms/epoch - 14ms/step
# Epoch 64/200
# 3/3 - 0s - loss: 0.0600 - accuracy: 0.9889 - val_loss: 0.1109 - val_accuracy: 0.9333 - 45ms/epoch - 15ms/step
# Epoch 65/200
# 3/3 - 0s - loss: 0.0605 - accuracy: 0.9889 - val_loss: 0.0951 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 66/200
# 3/3 - 0s - loss: 0.0614 - accuracy: 0.9889 - val_loss: 0.0664 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 67/200
# 3/3 - 0s - loss: 0.0607 - accuracy: 0.9889 - val_loss: 0.1002 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 68/200
# 3/3 - 0s - loss: 0.0584 - accuracy: 0.9889 - val_loss: 0.1489 - val_accuracy: 0.9333 - 40ms/epoch - 13ms/step
# Epoch 69/200
# 3/3 - 0s - loss: 0.0680 - accuracy: 0.9889 - val_loss: 0.1191 - val_accuracy: 0.9333 - 43ms/epoch - 14ms/step
# Epoch 70/200
# 3/3 - 0s - loss: 0.0581 - accuracy: 0.9889 - val_loss: 0.0511 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 71/200
# 3/3 - 0s - loss: 0.0746 - accuracy: 0.9778 - val_loss: 0.1284 - val_accuracy: 0.9333 - 47ms/epoch - 16ms/step
# Epoch 72/200
# 3/3 - 0s - loss: 0.1201 - accuracy: 0.9667 - val_loss: 0.3636 - val_accuracy: 0.8667 - 46ms/epoch - 15ms/step
# Epoch 73/200
# 3/3 - 0s - loss: 0.1394 - accuracy: 0.9556 - val_loss: 0.0833 - val_accuracy: 0.9667 - 40ms/epoch - 13ms/step
# Epoch 74/200
# 3/3 - 0s - loss: 0.1029 - accuracy: 0.9556 - val_loss: 0.0631 - val_accuracy: 0.9667 - 46ms/epoch - 15ms/step
# Epoch 75/200
# 3/3 - 0s - loss: 0.0899 - accuracy: 0.9778 - val_loss: 0.2922 - val_accuracy: 0.8667 - 46ms/epoch - 15ms/step
# Epoch 76/200
# 3/3 - 0s - loss: 0.1392 - accuracy: 0.9444 - val_loss: 0.1664 - val_accuracy: 0.9000 - 60ms/epoch - 20ms/step
# Epoch 77/200
# 3/3 - 0s - loss: 0.0889 - accuracy: 0.9667 - val_loss: 0.0662 - val_accuracy: 1.0000 - 59ms/epoch - 20ms/step
# Epoch 78/200
# 3/3 - 0s - loss: 0.1088 - accuracy: 0.9333 - val_loss: 0.0666 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 79/200
# 3/3 - 0s - loss: 0.0740 - accuracy: 0.9889 - val_loss: 0.1255 - val_accuracy: 0.9333 - 40ms/epoch - 13ms/step
# Epoch 80/200
# 3/3 - 0s - loss: 0.0723 - accuracy: 0.9889 - val_loss: 0.1408 - val_accuracy: 0.9000 - 44ms/epoch - 15ms/step
# Epoch 81/200
# 3/3 - 0s - loss: 0.0693 - accuracy: 0.9889 - val_loss: 0.0727 - val_accuracy: 0.9667 - 46ms/epoch - 15ms/step
# Epoch 82/200
# 3/3 - 0s - loss: 0.0644 - accuracy: 0.9889 - val_loss: 0.0845 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 83/200
# 3/3 - 0s - loss: 0.0630 - accuracy: 0.9889 - val_loss: 0.2092 - val_accuracy: 0.9000 - 45ms/epoch - 15ms/step
# Epoch 84/200
# 3/3 - 0s - loss: 0.0880 - accuracy: 0.9667 - val_loss: 0.1609 - val_accuracy: 0.9333 - 45ms/epoch - 15ms/step
# Epoch 85/200
# 3/3 - 0s - loss: 0.0625 - accuracy: 0.9889 - val_loss: 0.0542 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 86/200
# 3/3 - 0s - loss: 0.0824 - accuracy: 0.9778 - val_loss: 0.0409 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 87/200
# 3/3 - 0s - loss: 0.0648 - accuracy: 0.9889 - val_loss: 0.1072 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 88/200
# 3/3 - 0s - loss: 0.0618 - accuracy: 0.9889 - val_loss: 0.1219 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 89/200
# 3/3 - 0s - loss: 0.0554 - accuracy: 0.9889 - val_loss: 0.0466 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 90/200
# 3/3 - 0s - loss: 0.0766 - accuracy: 0.9667 - val_loss: 0.0637 - val_accuracy: 0.9667 - 40ms/epoch - 13ms/step
# Epoch 91/200
# 3/3 - 0s - loss: 0.0600 - accuracy: 0.9889 - val_loss: 0.1938 - val_accuracy: 0.9000 - 73ms/epoch - 24ms/step
# Epoch 92/200
# 3/3 - 0s - loss: 0.0833 - accuracy: 0.9778 - val_loss: 0.1522 - val_accuracy: 0.9000 - 58ms/epoch - 19ms/step
# Epoch 93/200
# 3/3 - 0s - loss: 0.0576 - accuracy: 0.9889 - val_loss: 0.0536 - val_accuracy: 0.9667 - 42ms/epoch - 14ms/step
# Epoch 94/200
# 3/3 - 0s - loss: 0.0700 - accuracy: 0.9778 - val_loss: 0.0472 - val_accuracy: 1.0000 - 41ms/epoch - 14ms/step
# Epoch 95/200
# 3/3 - 0s - loss: 0.0786 - accuracy: 0.9778 - val_loss: 0.1754 - val_accuracy: 0.9000 - 41ms/epoch - 14ms/step
# Epoch 96/200
# 3/3 - 0s - loss: 0.0865 - accuracy: 0.9667 - val_loss: 0.1970 - val_accuracy: 0.9000 - 40ms/epoch - 13ms/step
# Epoch 97/200
# 3/3 - 0s - loss: 0.0802 - accuracy: 0.9667 - val_loss: 0.0756 - val_accuracy: 0.9667 - 42ms/epoch - 14ms/step
# Epoch 98/200
# 3/3 - 0s - loss: 0.0960 - accuracy: 0.9556 - val_loss: 0.0631 - val_accuracy: 1.0000 - 44ms/epoch - 15ms/step
# Epoch 99/200
# 3/3 - 0s - loss: 0.1196 - accuracy: 0.9333 - val_loss: 0.0914 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 100/200
# 3/3 - 0s - loss: 0.0741 - accuracy: 0.9778 - val_loss: 0.2121 - val_accuracy: 0.8667 - 44ms/epoch - 15ms/step
# Epoch 101/200
# 3/3 - 0s - loss: 0.0907 - accuracy: 0.9667 - val_loss: 0.1314 - val_accuracy: 0.9333 - 43ms/epoch - 14ms/step
# Epoch 102/200
# 3/3 - 0s - loss: 0.0574 - accuracy: 0.9889 - val_loss: 0.0541 - val_accuracy: 0.9667 - 42ms/epoch - 14ms/step
# Epoch 103/200
# 3/3 - 0s - loss: 0.0806 - accuracy: 0.9889 - val_loss: 0.0475 - val_accuracy: 1.0000 - 44ms/epoch - 15ms/step
# Epoch 104/200
# 3/3 - 0s - loss: 0.0986 - accuracy: 0.9444 - val_loss: 0.1078 - val_accuracy: 0.9333 - 44ms/epoch - 15ms/step
# Epoch 105/200
# 3/3 - 0s - loss: 0.0810 - accuracy: 0.9778 - val_loss: 0.2190 - val_accuracy: 0.8667 - 44ms/epoch - 15ms/step
# Epoch 106/200
# 3/3 - 0s - loss: 0.0898 - accuracy: 0.9667 - val_loss: 0.1155 - val_accuracy: 0.9333 - 45ms/epoch - 15ms/step
# Epoch 107/200
# 3/3 - 0s - loss: 0.0572 - accuracy: 0.9889 - val_loss: 0.0581 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 108/200
# 3/3 - 0s - loss: 0.0683 - accuracy: 0.9889 - val_loss: 0.0541 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 109/200
# 3/3 - 0s - loss: 0.0603 - accuracy: 0.9889 - val_loss: 0.0915 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 110/200
# 3/3 - 0s - loss: 0.0539 - accuracy: 0.9889 - val_loss: 0.1409 - val_accuracy: 0.9333 - 41ms/epoch - 14ms/step
# Epoch 111/200
# 3/3 - 0s - loss: 0.0599 - accuracy: 0.9889 - val_loss: 0.1298 - val_accuracy: 0.9333 - 41ms/epoch - 14ms/step
# Epoch 112/200
# 3/3 - 0s - loss: 0.0572 - accuracy: 0.9889 - val_loss: 0.0902 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 113/200
# 3/3 - 0s - loss: 0.0538 - accuracy: 0.9889 - val_loss: 0.0384 - val_accuracy: 0.9667 - 50ms/epoch - 17ms/step
# Epoch 114/200
# 3/3 - 0s - loss: 0.0658 - accuracy: 0.9889 - val_loss: 0.0823 - val_accuracy: 0.9667 - 48ms/epoch - 16ms/step
# Epoch 115/200
# 3/3 - 0s - loss: 0.0571 - accuracy: 0.9889 - val_loss: 0.2117 - val_accuracy: 0.9000 - 49ms/epoch - 16ms/step
# Epoch 116/200
# 3/3 - 0s - loss: 0.0776 - accuracy: 0.9778 - val_loss: 0.1513 - val_accuracy: 0.9333 - 46ms/epoch - 15ms/step
# Epoch 117/200
# 3/3 - 0s - loss: 0.0565 - accuracy: 0.9889 - val_loss: 0.0396 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 118/200
# 3/3 - 0s - loss: 0.0631 - accuracy: 0.9889 - val_loss: 0.0480 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 119/200
# 3/3 - 0s - loss: 0.0570 - accuracy: 0.9889 - val_loss: 0.1049 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 120/200
# 3/3 - 0s - loss: 0.0539 - accuracy: 0.9889 - val_loss: 0.1195 - val_accuracy: 0.9333 - 43ms/epoch - 14ms/step
# Epoch 121/200
# 3/3 - 0s - loss: 0.0551 - accuracy: 0.9889 - val_loss: 0.1026 - val_accuracy: 0.9667 - 42ms/epoch - 14ms/step
# Epoch 122/200
# 3/3 - 0s - loss: 0.0528 - accuracy: 0.9889 - val_loss: 0.0797 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 123/200
# 3/3 - 0s - loss: 0.0524 - accuracy: 0.9889 - val_loss: 0.0703 - val_accuracy: 0.9667 - 40ms/epoch - 13ms/step
# Epoch 124/200
# 3/3 - 0s - loss: 0.0542 - accuracy: 0.9889 - val_loss: 0.0721 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 125/200
# 3/3 - 0s - loss: 0.0499 - accuracy: 0.9889 - val_loss: 0.0419 - val_accuracy: 0.9667 - 40ms/epoch - 13ms/step
# Epoch 126/200
# 3/3 - 0s - loss: 0.0577 - accuracy: 0.9889 - val_loss: 0.0744 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 127/200
# 3/3 - 0s - loss: 0.0497 - accuracy: 0.9889 - val_loss: 0.1229 - val_accuracy: 0.9333 - 42ms/epoch - 14ms/step
# Epoch 128/200
# 3/3 - 0s - loss: 0.0569 - accuracy: 0.9889 - val_loss: 0.1254 - val_accuracy: 0.9333 - 45ms/epoch - 15ms/step
# Epoch 129/200
# 3/3 - 0s - loss: 0.0554 - accuracy: 0.9889 - val_loss: 0.0737 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 130/200
# 3/3 - 0s - loss: 0.0509 - accuracy: 0.9889 - val_loss: 0.0659 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 131/200
# 3/3 - 0s - loss: 0.0515 - accuracy: 0.9889 - val_loss: 0.0834 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 132/200
# 3/3 - 0s - loss: 0.0511 - accuracy: 0.9889 - val_loss: 0.0928 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 133/200
# 3/3 - 0s - loss: 0.0513 - accuracy: 0.9889 - val_loss: 0.0835 - val_accuracy: 0.9667 - 40ms/epoch - 13ms/step
# Epoch 134/200
# 3/3 - 0s - loss: 0.0512 - accuracy: 0.9889 - val_loss: 0.0840 - val_accuracy: 0.9667 - 47ms/epoch - 16ms/step
# Epoch 135/200
# 3/3 - 0s - loss: 0.0517 - accuracy: 0.9889 - val_loss: 0.1129 - val_accuracy: 0.9667 - 46ms/epoch - 15ms/step
# Epoch 136/200
# 3/3 - 0s - loss: 0.0530 - accuracy: 0.9889 - val_loss: 0.1059 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 137/200
# 3/3 - 0s - loss: 0.0517 - accuracy: 0.9889 - val_loss: 0.0884 - val_accuracy: 0.9667 - 48ms/epoch - 16ms/step
# Epoch 138/200
# 3/3 - 0s - loss: 0.0512 - accuracy: 0.9889 - val_loss: 0.0660 - val_accuracy: 0.9667 - 47ms/epoch - 16ms/step
# Epoch 139/200
# 3/3 - 0s - loss: 0.0513 - accuracy: 0.9889 - val_loss: 0.0552 - val_accuracy: 0.9667 - 46ms/epoch - 15ms/step
# Epoch 140/200
# 3/3 - 0s - loss: 0.0535 - accuracy: 0.9889 - val_loss: 0.0612 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 141/200
# 3/3 - 0s - loss: 0.0488 - accuracy: 0.9889 - val_loss: 0.1060 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 142/200
# 3/3 - 0s - loss: 0.0562 - accuracy: 0.9889 - val_loss: 0.1290 - val_accuracy: 0.9333 - 45ms/epoch - 15ms/step
# Epoch 143/200
# 3/3 - 0s - loss: 0.0545 - accuracy: 0.9889 - val_loss: 0.0748 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 144/200
# 3/3 - 0s - loss: 0.0518 - accuracy: 0.9889 - val_loss: 0.0578 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 145/200
# 3/3 - 0s - loss: 0.0515 - accuracy: 0.9889 - val_loss: 0.0852 - val_accuracy: 0.9667 - 42ms/epoch - 14ms/step
# Epoch 146/200
# 3/3 - 0s - loss: 0.0476 - accuracy: 0.9889 - val_loss: 0.1857 - val_accuracy: 0.9000 - 39ms/epoch - 13ms/step
# Epoch 147/200
# 3/3 - 0s - loss: 0.0692 - accuracy: 0.9778 - val_loss: 0.1248 - val_accuracy: 0.9333 - 39ms/epoch - 13ms/step
# Epoch 148/200
# 3/3 - 0s - loss: 0.0497 - accuracy: 0.9889 - val_loss: 0.0309 - val_accuracy: 1.0000 - 41ms/epoch - 14ms/step
# Epoch 149/200
# 3/3 - 0s - loss: 0.0733 - accuracy: 0.9778 - val_loss: 0.0934 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 150/200
# 3/3 - 0s - loss: 0.0495 - accuracy: 0.9889 - val_loss: 0.1716 - val_accuracy: 0.9000 - 46ms/epoch - 15ms/step
# Epoch 151/200
# 3/3 - 0s - loss: 0.0660 - accuracy: 0.9778 - val_loss: 0.1032 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 152/200
# 3/3 - 0s - loss: 0.0510 - accuracy: 0.9889 - val_loss: 0.0474 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 153/200
# 3/3 - 0s - loss: 0.0610 - accuracy: 0.9889 - val_loss: 0.0724 - val_accuracy: 0.9667 - 56ms/epoch - 19ms/step
# Epoch 154/200
# 3/3 - 0s - loss: 0.0513 - accuracy: 0.9889 - val_loss: 0.1215 - val_accuracy: 0.9333 - 42ms/epoch - 14ms/step
# Epoch 155/200
# 3/3 - 0s - loss: 0.0527 - accuracy: 0.9889 - val_loss: 0.1022 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 156/200
# 3/3 - 0s - loss: 0.0500 - accuracy: 0.9889 - val_loss: 0.0809 - val_accuracy: 0.9667 - 39ms/epoch - 13ms/step
# Epoch 157/200
# 3/3 - 0s - loss: 0.0501 - accuracy: 0.9889 - val_loss: 0.0678 - val_accuracy: 0.9667 - 46ms/epoch - 15ms/step
# Epoch 158/200
# 3/3 - 0s - loss: 0.0527 - accuracy: 0.9889 - val_loss: 0.0711 - val_accuracy: 0.9667 - 46ms/epoch - 15ms/step
# Epoch 159/200
# 3/3 - 0s - loss: 0.0515 - accuracy: 0.9889 - val_loss: 0.0625 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 160/200
# 3/3 - 0s - loss: 0.0515 - accuracy: 0.9889 - val_loss: 0.0771 - val_accuracy: 0.9667 - 42ms/epoch - 14ms/step
# Epoch 161/200
# 3/3 - 0s - loss: 0.0512 - accuracy: 0.9889 - val_loss: 0.0951 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 162/200
# 3/3 - 0s - loss: 0.0501 - accuracy: 0.9889 - val_loss: 0.0746 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 163/200
# 3/3 - 0s - loss: 0.0521 - accuracy: 0.9889 - val_loss: 0.0716 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 164/200
# 3/3 - 0s - loss: 0.0509 - accuracy: 0.9889 - val_loss: 0.0951 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 165/200
# 3/3 - 0s - loss: 0.0509 - accuracy: 0.9889 - val_loss: 0.1114 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 166/200
# 3/3 - 0s - loss: 0.0493 - accuracy: 0.9889 - val_loss: 0.0736 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 167/200
# 3/3 - 0s - loss: 0.0538 - accuracy: 0.9889 - val_loss: 0.0630 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 168/200
# 3/3 - 0s - loss: 0.0501 - accuracy: 0.9889 - val_loss: 0.1414 - val_accuracy: 0.9333 - 41ms/epoch - 14ms/step
# Epoch 169/200
# 3/3 - 0s - loss: 0.0553 - accuracy: 0.9889 - val_loss: 0.1440 - val_accuracy: 0.9000 - 43ms/epoch - 14ms/step
# Epoch 170/200
# 3/3 - 0s - loss: 0.0506 - accuracy: 0.9889 - val_loss: 0.0785 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 171/200
# 3/3 - 0s - loss: 0.0567 - accuracy: 0.9889 - val_loss: 0.0561 - val_accuracy: 0.9667 - 62ms/epoch - 21ms/step
# Epoch 172/200
# 3/3 - 0s - loss: 0.0532 - accuracy: 0.9889 - val_loss: 0.1055 - val_accuracy: 0.9667 - 47ms/epoch - 16ms/step
# Epoch 173/200
# 3/3 - 0s - loss: 0.0526 - accuracy: 0.9889 - val_loss: 0.1939 - val_accuracy: 0.9000 - 49ms/epoch - 16ms/step
# Epoch 174/200
# 3/3 - 0s - loss: 0.0600 - accuracy: 0.9889 - val_loss: 0.1129 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 175/200
# 3/3 - 0s - loss: 0.0475 - accuracy: 0.9889 - val_loss: 0.0721 - val_accuracy: 0.9667 - 53ms/epoch - 18ms/step
# Epoch 176/200
# 3/3 - 0s - loss: 0.0485 - accuracy: 0.9889 - val_loss: 0.0593 - val_accuracy: 0.9667 - 42ms/epoch - 14ms/step
# Epoch 177/200
# 3/3 - 0s - loss: 0.0509 - accuracy: 0.9889 - val_loss: 0.1043 - val_accuracy: 0.9667 - 61ms/epoch - 20ms/step
# Epoch 178/200
# 3/3 - 0s - loss: 0.0493 - accuracy: 0.9889 - val_loss: 0.2907 - val_accuracy: 0.9000 - 51ms/epoch - 17ms/step
# Epoch 179/200
# 3/3 - 0s - loss: 0.0847 - accuracy: 0.9778 - val_loss: 0.0980 - val_accuracy: 0.9667 - 47ms/epoch - 16ms/step
# Epoch 180/200
# 3/3 - 0s - loss: 0.0634 - accuracy: 0.9667 - val_loss: 0.1149 - val_accuracy: 0.9667 - 58ms/epoch - 19ms/step
# Epoch 181/200
# 3/3 - 0s - loss: 0.0697 - accuracy: 0.9778 - val_loss: 0.4162 - val_accuracy: 0.8667 - 44ms/epoch - 15ms/step
# Epoch 182/200
# 3/3 - 0s - loss: 0.2057 - accuracy: 0.9000 - val_loss: 0.1769 - val_accuracy: 0.9000 - 58ms/epoch - 19ms/step
# Epoch 183/200
# 3/3 - 0s - loss: 0.0956 - accuracy: 0.9667 - val_loss: 0.0650 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 184/200
# 3/3 - 0s - loss: 0.0662 - accuracy: 0.9778 - val_loss: 0.2584 - val_accuracy: 0.8667 - 46ms/epoch - 15ms/step
# Epoch 185/200
# 3/3 - 0s - loss: 0.1063 - accuracy: 0.9444 - val_loss: 0.1492 - val_accuracy: 0.9000 - 56ms/epoch - 19ms/step
# Epoch 186/200
# 3/3 - 0s - loss: 0.0555 - accuracy: 0.9889 - val_loss: 0.0498 - val_accuracy: 0.9667 - 46ms/epoch - 15ms/step
# Epoch 187/200
# 3/3 - 0s - loss: 0.0690 - accuracy: 0.9889 - val_loss: 0.0533 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 188/200
# 3/3 - 0s - loss: 0.0529 - accuracy: 0.9889 - val_loss: 0.0954 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 189/200
# 3/3 - 0s - loss: 0.0480 - accuracy: 0.9889 - val_loss: 0.1535 - val_accuracy: 0.9000 - 43ms/epoch - 14ms/step
# Epoch 190/200
# 3/3 - 0s - loss: 0.0547 - accuracy: 0.9889 - val_loss: 0.1422 - val_accuracy: 0.9333 - 47ms/epoch - 16ms/step
# Epoch 191/200
# 3/3 - 0s - loss: 0.0539 - accuracy: 0.9889 - val_loss: 0.0974 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 192/200
# 3/3 - 0s - loss: 0.0509 - accuracy: 0.9889 - val_loss: 0.0761 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 193/200
# 3/3 - 0s - loss: 0.0495 - accuracy: 0.9889 - val_loss: 0.0822 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 194/200
# 3/3 - 0s - loss: 0.0489 - accuracy: 0.9889 - val_loss: 0.0874 - val_accuracy: 0.9667 - 46ms/epoch - 15ms/step
# Epoch 195/200
# 3/3 - 0s - loss: 0.0483 - accuracy: 0.9889 - val_loss: 0.0951 - val_accuracy: 0.9667 - 50ms/epoch - 17ms/step
# Epoch 196/200
# 3/3 - 0s - loss: 0.0484 - accuracy: 0.9889 - val_loss: 0.1008 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step
# Epoch 197/200
# 3/3 - 0s - loss: 0.0494 - accuracy: 0.9889 - val_loss: 0.1080 - val_accuracy: 0.9667 - 46ms/epoch - 15ms/step
# Epoch 198/200
# 3/3 - 0s - loss: 0.0494 - accuracy: 0.9889 - val_loss: 0.0937 - val_accuracy: 0.9667 - 49ms/epoch - 16ms/step
# Epoch 199/200
# 3/3 - 0s - loss: 0.0479 - accuracy: 0.9889 - val_loss: 0.0833 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 200/200
# 3/3 - 0s - loss: 0.0473 - accuracy: 0.9889 - val_loss: 0.0801 - val_accuracy: 0.9667 - 41ms/epoch - 14ms/step

# %% [markdown]
# ### Model Evaluation

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_'+metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and validation '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_'+metric])
    plt.show()

# %%
plot_metric(history, 'accuracy')

# %%
plot_metric(history, 'loss')

# %% [markdown]
# ### Plot the training and validation loss
#
# plotting the loss vs. epochs graph on the training and validation sets
# From the graph, it can be seen that the model has vastly overfitted the training data, so it outperform the validation set

# %%
# Evaluate the model on the test set
model.evaluate(X_test, y_test, verbose=2)
# Out:
# 1/1 - 0s - loss: 0.0791 - accuracy: 0.9333 - 28ms/epoch - 28ms/step
# [0.07908161729574203, 0.9333333373069763]

# %% [markdown]
# ## 2. Adding L2 regularization and Dropout

# %% [markdown]
# ## Import Dropout and L2 regularization from TensorFlow Keras package

# %% [markdown]
# Create a function called create_regularized_model() that will return a model similar to the one we built before.
# However, L2 regularization and Dropout layers are added.
# The function will take 2 arguments: a L2 regularization factor and a Dropout rate.
#
#     Add L2 regularization in all layers except the output layer [1].
#     Add Dropout layer between every two dense layers.

# %%
from tensorflow.keras.layers import Dropout
from tensorflow.keras.regularizers import l2

def create_regularized_model(factor, rate):
    model = Sequential([
        Dense(64, kernel_regularizer=l2(factor), activation="relu", input_shape=(4,)),
        Dropout(rate),
        Dense(128, kernel_regularizer=l2(factor), activation="relu"),
        Dropout(rate),
        Dense(128, kernel_regularizer=l2(factor), activation="relu"),
        Dropout(rate),
        Dense(128, kernel_regularizer=l2(factor), activation="relu"),
        Dropout(rate),
        Dense(64, kernel_regularizer=l2(factor), activation="relu"),
        Dropout(rate),
        Dense(64, kernel_regularizer=l2(factor), activation="relu"),
        Dropout(rate),
        Dense(64, kernel_regularizer=l2(factor), activation="relu"),
        Dropout(rate),
        Dense(3, activation='softmax')
    ])
    return model

# %%
# Re-build the model with weight decay and dropout layers
model = create_regularized_model(1e-5, 0.3)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 64)                320
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_9 (Dense)             (None, 128)               8320
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_10 (Dense)            (None, 128)               16512
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_11 (Dense)            (None, 128)               16512
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_12 (Dense)            (None, 64)                8256
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_13 (Dense)            (None, 64)                4160
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_14 (Dense)            (None, 64)                4160
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_15 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 58,435
# Trainable params: 58,435
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(
    optimizer='adam', 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
# Train the model, with some of the data reserved for validation
history = model.fit(
    X_train, 
    y_train, 
    epochs=200, 
    validation_split=0.25, 
    batch_size=40, 
    verbose=2
)
# Out:
# Epoch 1/200
# 3/3 - 2s - loss: 1.1034 - accuracy: 0.3667 - val_loss: 1.1003 - val_accuracy: 0.3000 - 2s/epoch - 772ms/step
# Epoch 2/200
# 3/3 - 0s - loss: 1.1096 - accuracy: 0.3556 - val_loss: 1.0937 - val_accuracy: 0.3000 - 45ms/epoch - 15ms/step
# Epoch 3/200
# 3/3 - 0s - loss: 1.0565 - accuracy: 0.4667 - val_loss: 1.0963 - val_accuracy: 0.3000 - 53ms/epoch - 18ms/step
# Epoch 4/200
# 3/3 - 0s - loss: 1.1430 - accuracy: 0.3000 - val_loss: 1.0910 - val_accuracy: 0.3000 - 53ms/epoch - 18ms/step
# Epoch 5/200
# 3/3 - 0s - loss: 1.0802 - accuracy: 0.4111 - val_loss: 1.0665 - val_accuracy: 0.3000 - 45ms/epoch - 15ms/step
# Epoch 6/200
# 3/3 - 0s - loss: 1.0879 - accuracy: 0.4000 - val_loss: 1.0363 - val_accuracy: 0.3000 - 46ms/epoch - 15ms/step
# Epoch 7/200
# 3/3 - 0s - loss: 1.0237 - accuracy: 0.4444 - val_loss: 1.0190 - val_accuracy: 0.3000 - 57ms/epoch - 19ms/step
# Epoch 8/200
# 3/3 - 0s - loss: 1.0021 - accuracy: 0.5222 - val_loss: 0.9996 - val_accuracy: 0.3000 - 73ms/epoch - 24ms/step
# Epoch 9/200
# 3/3 - 0s - loss: 1.0234 - accuracy: 0.4556 - val_loss: 0.9830 - val_accuracy: 0.3000 - 46ms/epoch - 15ms/step
# Epoch 10/200
# 3/3 - 0s - loss: 1.0560 - accuracy: 0.3889 - val_loss: 0.9636 - val_accuracy: 0.3000 - 45ms/epoch - 15ms/step
# Epoch 11/200
# 3/3 - 0s - loss: 0.9493 - accuracy: 0.5333 - val_loss: 0.9389 - val_accuracy: 0.4667 - 45ms/epoch - 15ms/step
# Epoch 12/200
# 3/3 - 0s - loss: 0.9825 - accuracy: 0.4333 - val_loss: 0.9131 - val_accuracy: 0.6000 - 44ms/epoch - 15ms/step
# Epoch 13/200
# 3/3 - 0s - loss: 0.9625 - accuracy: 0.5333 - val_loss: 0.8876 - val_accuracy: 0.6000 - 47ms/epoch - 16ms/step
# Epoch 14/200
# 3/3 - 0s - loss: 0.9190 - accuracy: 0.5556 - val_loss: 0.8652 - val_accuracy: 0.6000 - 47ms/epoch - 16ms/step
# Epoch 15/200
# 3/3 - 0s - loss: 0.9151 - accuracy: 0.6111 - val_loss: 0.8446 - val_accuracy: 0.6000 - 44ms/epoch - 15ms/step
# Epoch 16/200
# 3/3 - 0s - loss: 0.8737 - accuracy: 0.5889 - val_loss: 0.8210 - val_accuracy: 0.6000 - 44ms/epoch - 15ms/step
# Epoch 17/200
# 3/3 - 0s - loss: 0.8461 - accuracy: 0.6111 - val_loss: 0.7982 - val_accuracy: 0.6000 - 43ms/epoch - 14ms/step
# Epoch 18/200
# 3/3 - 0s - loss: 0.8453 - accuracy: 0.6667 - val_loss: 0.7795 - val_accuracy: 0.6000 - 60ms/epoch - 20ms/step
# Epoch 19/200
# 3/3 - 0s - loss: 0.8068 - accuracy: 0.6444 - val_loss: 0.7643 - val_accuracy: 0.6000 - 49ms/epoch - 16ms/step
# Epoch 20/200
# 3/3 - 0s - loss: 0.7638 - accuracy: 0.6778 - val_loss: 0.7379 - val_accuracy: 0.6000 - 46ms/epoch - 15ms/step
# Epoch 21/200
# 3/3 - 0s - loss: 0.7328 - accuracy: 0.6667 - val_loss: 0.6999 - val_accuracy: 0.6000 - 47ms/epoch - 16ms/step
# Epoch 22/200
# 3/3 - 0s - loss: 0.6421 - accuracy: 0.7000 - val_loss: 0.6634 - val_accuracy: 0.6000 - 53ms/epoch - 18ms/step
# Epoch 23/200
# 3/3 - 0s - loss: 0.6625 - accuracy: 0.6556 - val_loss: 0.6314 - val_accuracy: 0.6000 - 45ms/epoch - 15ms/step
# Epoch 24/200
# 3/3 - 0s - loss: 0.6035 - accuracy: 0.7333 - val_loss: 0.6005 - val_accuracy: 0.6000 - 50ms/epoch - 17ms/step
# Epoch 25/200
# 3/3 - 0s - loss: 0.6124 - accuracy: 0.7111 - val_loss: 0.5732 - val_accuracy: 0.6000 - 52ms/epoch - 17ms/step
# Epoch 26/200
# 3/3 - 0s - loss: 0.5239 - accuracy: 0.7333 - val_loss: 0.5607 - val_accuracy: 0.6000 - 50ms/epoch - 17ms/step
# Epoch 27/200
# 3/3 - 0s - loss: 0.5585 - accuracy: 0.7444 - val_loss: 0.5426 - val_accuracy: 0.6000 - 54ms/epoch - 18ms/step
# Epoch 28/200
# 3/3 - 0s - loss: 0.5459 - accuracy: 0.6889 - val_loss: 0.5143 - val_accuracy: 0.6000 - 46ms/epoch - 15ms/step
# Epoch 29/200
# 3/3 - 0s - loss: 0.4643 - accuracy: 0.7222 - val_loss: 0.4911 - val_accuracy: 0.6000 - 43ms/epoch - 14ms/step
# Epoch 30/200
# 3/3 - 0s - loss: 0.5283 - accuracy: 0.6667 - val_loss: 0.4893 - val_accuracy: 0.6000 - 44ms/epoch - 15ms/step
# Epoch 31/200
# 3/3 - 0s - loss: 0.5471 - accuracy: 0.6889 - val_loss: 0.4941 - val_accuracy: 0.6000 - 44ms/epoch - 15ms/step
# Epoch 32/200
# 3/3 - 0s - loss: 0.5215 - accuracy: 0.6889 - val_loss: 0.4934 - val_accuracy: 0.6000 - 51ms/epoch - 17ms/step
# Epoch 33/200
# 3/3 - 0s - loss: 0.5320 - accuracy: 0.6889 - val_loss: 0.4976 - val_accuracy: 0.6000 - 46ms/epoch - 15ms/step
# Epoch 34/200
# 3/3 - 0s - loss: 0.4607 - accuracy: 0.6778 - val_loss: 0.4971 - val_accuracy: 0.6000 - 43ms/epoch - 14ms/step
# Epoch 35/200
# 3/3 - 0s - loss: 0.4310 - accuracy: 0.7444 - val_loss: 0.4979 - val_accuracy: 0.6000 - 50ms/epoch - 17ms/step
# Epoch 36/200
# 3/3 - 0s - loss: 0.4728 - accuracy: 0.7111 - val_loss: 0.4994 - val_accuracy: 0.6000 - 51ms/epoch - 17ms/step
# Epoch 37/200
# 3/3 - 0s - loss: 0.5136 - accuracy: 0.7444 - val_loss: 0.5019 - val_accuracy: 0.6000 - 50ms/epoch - 17ms/step
# Epoch 38/200
# 3/3 - 0s - loss: 0.4904 - accuracy: 0.6778 - val_loss: 0.4991 - val_accuracy: 0.6000 - 52ms/epoch - 17ms/step
# Epoch 39/200
# 3/3 - 0s - loss: 0.5098 - accuracy: 0.7111 - val_loss: 0.4905 - val_accuracy: 0.6000 - 63ms/epoch - 21ms/step
# Epoch 40/200
# 3/3 - 0s - loss: 0.4283 - accuracy: 0.7444 - val_loss: 0.4856 - val_accuracy: 0.6000 - 42ms/epoch - 14ms/step
# Epoch 41/200
# 3/3 - 0s - loss: 0.4763 - accuracy: 0.7556 - val_loss: 0.4769 - val_accuracy: 0.6000 - 48ms/epoch - 16ms/step
# Epoch 42/200
# 3/3 - 0s - loss: 0.4614 - accuracy: 0.7111 - val_loss: 0.4716 - val_accuracy: 0.6333 - 49ms/epoch - 16ms/step
# Epoch 43/200
# 3/3 - 0s - loss: 0.4720 - accuracy: 0.7444 - val_loss: 0.4696 - val_accuracy: 0.6333 - 50ms/epoch - 17ms/step
# Epoch 44/200
# 3/3 - 0s - loss: 0.4443 - accuracy: 0.7111 - val_loss: 0.4695 - val_accuracy: 0.6333 - 52ms/epoch - 17ms/step
# Epoch 45/200
# 3/3 - 0s - loss: 0.4400 - accuracy: 0.7778 - val_loss: 0.4707 - val_accuracy: 0.6000 - 51ms/epoch - 17ms/step
# Epoch 46/200
# 3/3 - 0s - loss: 0.4878 - accuracy: 0.7444 - val_loss: 0.4752 - val_accuracy: 0.6000 - 54ms/epoch - 18ms/step
# Epoch 47/200
# 3/3 - 0s - loss: 0.4169 - accuracy: 0.7444 - val_loss: 0.4923 - val_accuracy: 0.6000 - 47ms/epoch - 16ms/step
# Epoch 48/200
# 3/3 - 0s - loss: 0.4413 - accuracy: 0.7222 - val_loss: 0.5083 - val_accuracy: 0.6000 - 48ms/epoch - 16ms/step
# Epoch 49/200
# 3/3 - 0s - loss: 0.4632 - accuracy: 0.7222 - val_loss: 0.5066 - val_accuracy: 0.6000 - 50ms/epoch - 17ms/step
# Epoch 50/200
# 3/3 - 0s - loss: 0.4126 - accuracy: 0.7444 - val_loss: 0.4964 - val_accuracy: 0.6000 - 48ms/epoch - 16ms/step
# Epoch 51/200
# 3/3 - 0s - loss: 0.4569 - accuracy: 0.7222 - val_loss: 0.4812 - val_accuracy: 0.6000 - 48ms/epoch - 16ms/step
# Epoch 52/200
# 3/3 - 0s - loss: 0.4457 - accuracy: 0.7333 - val_loss: 0.4667 - val_accuracy: 0.6333 - 47ms/epoch - 16ms/step
# Epoch 53/200
# 3/3 - 0s - loss: 0.4815 - accuracy: 0.7222 - val_loss: 0.4619 - val_accuracy: 0.6333 - 44ms/epoch - 15ms/step
# Epoch 54/200
# 3/3 - 0s - loss: 0.3934 - accuracy: 0.7556 - val_loss: 0.4677 - val_accuracy: 0.6667 - 43ms/epoch - 14ms/step
# Epoch 55/200
# 3/3 - 0s - loss: 0.5190 - accuracy: 0.7444 - val_loss: 0.4597 - val_accuracy: 0.6333 - 46ms/epoch - 15ms/step
# Epoch 56/200
# 3/3 - 0s - loss: 0.4568 - accuracy: 0.7778 - val_loss: 0.4617 - val_accuracy: 0.6333 - 51ms/epoch - 17ms/step
# Epoch 57/200
# 3/3 - 0s - loss: 0.4218 - accuracy: 0.7333 - val_loss: 0.4644 - val_accuracy: 0.6333 - 46ms/epoch - 15ms/step
# Epoch 58/200
# 3/3 - 0s - loss: 0.4286 - accuracy: 0.7222 - val_loss: 0.4671 - val_accuracy: 0.6333 - 49ms/epoch - 16ms/step
# Epoch 59/200
# 3/3 - 0s - loss: 0.3979 - accuracy: 0.8000 - val_loss: 0.4654 - val_accuracy: 0.6333 - 49ms/epoch - 16ms/step
# Epoch 60/200
# 3/3 - 0s - loss: 0.4162 - accuracy: 0.7556 - val_loss: 0.4622 - val_accuracy: 0.6333 - 55ms/epoch - 18ms/step
# Epoch 61/200
# 3/3 - 0s - loss: 0.4143 - accuracy: 0.7333 - val_loss: 0.4582 - val_accuracy: 0.6333 - 48ms/epoch - 16ms/step
# Epoch 62/200
# 3/3 - 0s - loss: 0.4140 - accuracy: 0.7222 - val_loss: 0.4577 - val_accuracy: 0.6333 - 49ms/epoch - 16ms/step
# Epoch 63/200
# 3/3 - 0s - loss: 0.3906 - accuracy: 0.7333 - val_loss: 0.4580 - val_accuracy: 0.6333 - 44ms/epoch - 15ms/step
# Epoch 64/200
# 3/3 - 0s - loss: 0.4783 - accuracy: 0.7444 - val_loss: 0.4661 - val_accuracy: 0.6333 - 48ms/epoch - 16ms/step
# Epoch 65/200
# 3/3 - 0s - loss: 0.3954 - accuracy: 0.7889 - val_loss: 0.4640 - val_accuracy: 0.6333 - 44ms/epoch - 15ms/step
# Epoch 66/200
# 3/3 - 0s - loss: 0.4345 - accuracy: 0.7444 - val_loss: 0.4537 - val_accuracy: 0.6333 - 46ms/epoch - 15ms/step
# Epoch 67/200
# 3/3 - 0s - loss: 0.3809 - accuracy: 0.7667 - val_loss: 0.4417 - val_accuracy: 0.7000 - 43ms/epoch - 14ms/step
# Epoch 68/200
# 3/3 - 0s - loss: 0.3835 - accuracy: 0.8222 - val_loss: 0.4383 - val_accuracy: 0.7333 - 65ms/epoch - 22ms/step
# Epoch 69/200
# 3/3 - 0s - loss: 0.4155 - accuracy: 0.8000 - val_loss: 0.4353 - val_accuracy: 0.7000 - 43ms/epoch - 14ms/step
# Epoch 70/200
# 3/3 - 0s - loss: 0.4074 - accuracy: 0.7889 - val_loss: 0.4413 - val_accuracy: 0.6333 - 45ms/epoch - 15ms/step
# Epoch 71/200
# 3/3 - 0s - loss: 0.4193 - accuracy: 0.8111 - val_loss: 0.4566 - val_accuracy: 0.6333 - 47ms/epoch - 16ms/step
# Epoch 72/200
# 3/3 - 0s - loss: 0.4578 - accuracy: 0.7000 - val_loss: 0.4528 - val_accuracy: 0.6333 - 46ms/epoch - 15ms/step
# Epoch 73/200
# 3/3 - 0s - loss: 0.3987 - accuracy: 0.7444 - val_loss: 0.4340 - val_accuracy: 0.6667 - 49ms/epoch - 16ms/step
# Epoch 74/200
# 3/3 - 0s - loss: 0.3925 - accuracy: 0.7333 - val_loss: 0.4233 - val_accuracy: 0.7667 - 48ms/epoch - 16ms/step
# Epoch 75/200
# 3/3 - 0s - loss: 0.4125 - accuracy: 0.7889 - val_loss: 0.4281 - val_accuracy: 0.8667 - 47ms/epoch - 16ms/step
# Epoch 76/200
# 3/3 - 0s - loss: 0.4097 - accuracy: 0.8333 - val_loss: 0.4200 - val_accuracy: 0.8333 - 50ms/epoch - 17ms/step
# Epoch 77/200
# 3/3 - 0s - loss: 0.4035 - accuracy: 0.8000 - val_loss: 0.4186 - val_accuracy: 0.7333 - 49ms/epoch - 16ms/step
# Epoch 78/200
# 3/3 - 0s - loss: 0.4150 - accuracy: 0.8111 - val_loss: 0.4251 - val_accuracy: 0.7000 - 46ms/epoch - 15ms/step
# Epoch 79/200
# 3/3 - 0s - loss: 0.4452 - accuracy: 0.8111 - val_loss: 0.4228 - val_accuracy: 0.7000 - 51ms/epoch - 17ms/step
# Epoch 80/200
# 3/3 - 0s - loss: 0.4020 - accuracy: 0.7778 - val_loss: 0.4146 - val_accuracy: 0.7667 - 47ms/epoch - 16ms/step
# Epoch 81/200
# 3/3 - 0s - loss: 0.3946 - accuracy: 0.8222 - val_loss: 0.4108 - val_accuracy: 0.8000 - 46ms/epoch - 15ms/step
# Epoch 82/200
# 3/3 - 0s - loss: 0.3890 - accuracy: 0.8222 - val_loss: 0.4065 - val_accuracy: 0.8333 - 49ms/epoch - 16ms/step
# Epoch 83/200
# 3/3 - 0s - loss: 0.3755 - accuracy: 0.8111 - val_loss: 0.4032 - val_accuracy: 0.8667 - 46ms/epoch - 15ms/step
# Epoch 84/200
# 3/3 - 0s - loss: 0.3531 - accuracy: 0.8556 - val_loss: 0.3977 - val_accuracy: 0.8333 - 43ms/epoch - 14ms/step
# Epoch 85/200
# 3/3 - 0s - loss: 0.3913 - accuracy: 0.8222 - val_loss: 0.3928 - val_accuracy: 0.8333 - 44ms/epoch - 15ms/step
# Epoch 86/200
# 3/3 - 0s - loss: 0.4112 - accuracy: 0.7778 - val_loss: 0.3873 - val_accuracy: 0.8333 - 45ms/epoch - 15ms/step
# Epoch 87/200
# 3/3 - 0s - loss: 0.3558 - accuracy: 0.7889 - val_loss: 0.3821 - val_accuracy: 0.8333 - 44ms/epoch - 15ms/step
# Epoch 88/200
# 3/3 - 0s - loss: 0.3440 - accuracy: 0.7889 - val_loss: 0.3792 - val_accuracy: 0.8333 - 45ms/epoch - 15ms/step
# Epoch 89/200
# 3/3 - 0s - loss: 0.3606 - accuracy: 0.8111 - val_loss: 0.3771 - val_accuracy: 0.8333 - 48ms/epoch - 16ms/step
# Epoch 90/200
# 3/3 - 0s - loss: 0.3592 - accuracy: 0.8444 - val_loss: 0.3756 - val_accuracy: 0.8333 - 46ms/epoch - 15ms/step
# Epoch 91/200
# 3/3 - 0s - loss: 0.3514 - accuracy: 0.8333 - val_loss: 0.3718 - val_accuracy: 0.8333 - 49ms/epoch - 16ms/step
# Epoch 92/200
# 3/3 - 0s - loss: 0.3338 - accuracy: 0.8222 - val_loss: 0.3671 - val_accuracy: 0.8667 - 46ms/epoch - 15ms/step
# Epoch 93/200
# 3/3 - 0s - loss: 0.3221 - accuracy: 0.8333 - val_loss: 0.3634 - val_accuracy: 0.8667 - 45ms/epoch - 15ms/step
# Epoch 94/200
# 3/3 - 0s - loss: 0.3859 - accuracy: 0.8333 - val_loss: 0.3620 - val_accuracy: 0.9000 - 45ms/epoch - 15ms/step
# Epoch 95/200
# 3/3 - 0s - loss: 0.3600 - accuracy: 0.8778 - val_loss: 0.3589 - val_accuracy: 0.8667 - 45ms/epoch - 15ms/step
# Epoch 96/200
# 3/3 - 0s - loss: 0.3664 - accuracy: 0.8000 - val_loss: 0.3679 - val_accuracy: 0.8333 - 44ms/epoch - 15ms/step
# Epoch 97/200
# 3/3 - 0s - loss: 0.4071 - accuracy: 0.8222 - val_loss: 0.3505 - val_accuracy: 0.8667 - 46ms/epoch - 15ms/step
# Epoch 98/200
# 3/3 - 0s - loss: 0.3388 - accuracy: 0.8444 - val_loss: 0.3577 - val_accuracy: 0.9333 - 44ms/epoch - 15ms/step
# Epoch 99/200
# 3/3 - 0s - loss: 0.3576 - accuracy: 0.9000 - val_loss: 0.3779 - val_accuracy: 0.9667 - 48ms/epoch - 16ms/step
# Epoch 100/200
# 3/3 - 0s - loss: 0.3678 - accuracy: 0.8667 - val_loss: 0.3697 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 101/200
# 3/3 - 0s - loss: 0.3215 - accuracy: 0.8889 - val_loss: 0.3437 - val_accuracy: 0.9333 - 47ms/epoch - 16ms/step
# Epoch 102/200
# 3/3 - 0s - loss: 0.3166 - accuracy: 0.9222 - val_loss: 0.3319 - val_accuracy: 0.9000 - 48ms/epoch - 16ms/step
# Epoch 103/200
# 3/3 - 0s - loss: 0.3454 - accuracy: 0.8556 - val_loss: 0.3286 - val_accuracy: 0.8667 - 46ms/epoch - 15ms/step
# Epoch 104/200
# 3/3 - 0s - loss: 0.3588 - accuracy: 0.8889 - val_loss: 0.3231 - val_accuracy: 0.9000 - 48ms/epoch - 16ms/step
# Epoch 105/200
# 3/3 - 0s - loss: 0.3041 - accuracy: 0.8778 - val_loss: 0.3202 - val_accuracy: 0.9333 - 44ms/epoch - 15ms/step
# Epoch 106/200
# 3/3 - 0s - loss: 0.2972 - accuracy: 0.8778 - val_loss: 0.3172 - val_accuracy: 0.9333 - 45ms/epoch - 15ms/step
# Epoch 107/200
# 3/3 - 0s - loss: 0.3173 - accuracy: 0.9333 - val_loss: 0.3146 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 108/200
# 3/3 - 0s - loss: 0.2998 - accuracy: 0.9111 - val_loss: 0.3158 - val_accuracy: 0.9667 - 47ms/epoch - 16ms/step
# Epoch 109/200
# 3/3 - 0s - loss: 0.3772 - accuracy: 0.9111 - val_loss: 0.2994 - val_accuracy: 0.9333 - 47ms/epoch - 16ms/step
# Epoch 110/200
# 3/3 - 0s - loss: 0.2790 - accuracy: 0.9000 - val_loss: 0.3001 - val_accuracy: 0.9000 - 47ms/epoch - 16ms/step
# Epoch 111/200
# 3/3 - 0s - loss: 0.3053 - accuracy: 0.9222 - val_loss: 0.2984 - val_accuracy: 0.9000 - 48ms/epoch - 16ms/step
# Epoch 112/200
# 3/3 - 0s - loss: 0.2815 - accuracy: 0.9111 - val_loss: 0.2865 - val_accuracy: 0.9333 - 49ms/epoch - 16ms/step
# Epoch 113/200
# 3/3 - 0s - loss: 0.3759 - accuracy: 0.8667 - val_loss: 0.2801 - val_accuracy: 0.9667 - 47ms/epoch - 16ms/step
# Epoch 114/200
# 3/3 - 0s - loss: 0.2903 - accuracy: 0.9222 - val_loss: 0.2776 - val_accuracy: 0.9667 - 47ms/epoch - 16ms/step
# Epoch 115/200
# 3/3 - 0s - loss: 0.2994 - accuracy: 0.9111 - val_loss: 0.2732 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 116/200
# 3/3 - 0s - loss: 0.2931 - accuracy: 0.9556 - val_loss: 0.2698 - val_accuracy: 0.9667 - 46ms/epoch - 15ms/step
# Epoch 117/200
# 3/3 - 0s - loss: 0.3100 - accuracy: 0.9333 - val_loss: 0.2646 - val_accuracy: 0.9667 - 48ms/epoch - 16ms/step
# Epoch 118/200
# 3/3 - 0s - loss: 0.2840 - accuracy: 0.8889 - val_loss: 0.2592 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 119/200
# 3/3 - 0s - loss: 0.2722 - accuracy: 0.8889 - val_loss: 0.2548 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 120/200
# 3/3 - 0s - loss: 0.3007 - accuracy: 0.9111 - val_loss: 0.2531 - val_accuracy: 0.9667 - 49ms/epoch - 16ms/step
# Epoch 121/200
# 3/3 - 0s - loss: 0.3156 - accuracy: 0.9222 - val_loss: 0.2596 - val_accuracy: 0.9333 - 48ms/epoch - 16ms/step
# Epoch 122/200
# 3/3 - 0s - loss: 0.3252 - accuracy: 0.9111 - val_loss: 0.2486 - val_accuracy: 0.9667 - 47ms/epoch - 16ms/step
# Epoch 123/200
# 3/3 - 0s - loss: 0.2786 - accuracy: 0.9222 - val_loss: 0.2530 - val_accuracy: 0.9667 - 50ms/epoch - 17ms/step
# Epoch 124/200
# 3/3 - 0s - loss: 0.3214 - accuracy: 0.9000 - val_loss: 0.2738 - val_accuracy: 1.0000 - 51ms/epoch - 17ms/step
# Epoch 125/200
# 3/3 - 0s - loss: 0.2389 - accuracy: 0.9444 - val_loss: 0.2440 - val_accuracy: 0.9667 - 51ms/epoch - 17ms/step
# Epoch 126/200
# 3/3 - 0s - loss: 0.2433 - accuracy: 0.9333 - val_loss: 0.2394 - val_accuracy: 0.9667 - 46ms/epoch - 15ms/step
# Epoch 127/200
# 3/3 - 0s - loss: 0.2355 - accuracy: 0.9222 - val_loss: 0.2766 - val_accuracy: 0.9000 - 52ms/epoch - 17ms/step
# Epoch 128/200
# 3/3 - 0s - loss: 0.2539 - accuracy: 0.9333 - val_loss: 0.2916 - val_accuracy: 0.9000 - 46ms/epoch - 15ms/step
# Epoch 129/200
# 3/3 - 0s - loss: 0.2137 - accuracy: 0.9222 - val_loss: 0.2262 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 130/200
# 3/3 - 0s - loss: 0.3118 - accuracy: 0.9444 - val_loss: 0.2044 - val_accuracy: 0.9667 - 47ms/epoch - 16ms/step
# Epoch 131/200
# 3/3 - 0s - loss: 0.2289 - accuracy: 0.9222 - val_loss: 0.1992 - val_accuracy: 1.0000 - 44ms/epoch - 15ms/step
# Epoch 132/200
# 3/3 - 0s - loss: 0.2605 - accuracy: 0.9333 - val_loss: 0.1884 - val_accuracy: 0.9667 - 47ms/epoch - 16ms/step
# Epoch 133/200
# 3/3 - 0s - loss: 0.2271 - accuracy: 0.9333 - val_loss: 0.2079 - val_accuracy: 0.9667 - 47ms/epoch - 16ms/step
# Epoch 134/200
# 3/3 - 0s - loss: 0.2649 - accuracy: 0.9444 - val_loss: 0.2087 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 135/200
# 3/3 - 0s - loss: 0.2082 - accuracy: 0.9667 - val_loss: 0.1928 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 136/200
# 3/3 - 0s - loss: 0.2186 - accuracy: 0.9111 - val_loss: 0.1628 - val_accuracy: 0.9667 - 47ms/epoch - 16ms/step
# Epoch 137/200
# 3/3 - 0s - loss: 0.2005 - accuracy: 0.9444 - val_loss: 0.1467 - val_accuracy: 1.0000 - 46ms/epoch - 15ms/step
# Epoch 138/200
# 3/3 - 0s - loss: 0.2161 - accuracy: 0.9222 - val_loss: 0.1392 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 139/200
# 3/3 - 0s - loss: 0.2099 - accuracy: 0.9556 - val_loss: 0.1440 - val_accuracy: 0.9667 - 53ms/epoch - 18ms/step
# Epoch 140/200
# 3/3 - 0s - loss: 0.1907 - accuracy: 0.9556 - val_loss: 0.1852 - val_accuracy: 0.9667 - 46ms/epoch - 15ms/step
# Epoch 141/200
# 3/3 - 0s - loss: 0.2485 - accuracy: 0.9444 - val_loss: 0.1832 - val_accuracy: 0.9333 - 48ms/epoch - 16ms/step
# Epoch 142/200
# 3/3 - 0s - loss: 0.1627 - accuracy: 0.9444 - val_loss: 0.1444 - val_accuracy: 0.9667 - 46ms/epoch - 15ms/step
# Epoch 143/200
# 3/3 - 0s - loss: 0.2402 - accuracy: 0.9111 - val_loss: 0.1156 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 144/200
# 3/3 - 0s - loss: 0.1846 - accuracy: 0.9333 - val_loss: 0.0973 - val_accuracy: 1.0000 - 47ms/epoch - 16ms/step
# Epoch 145/200
# 3/3 - 0s - loss: 0.2150 - accuracy: 0.9222 - val_loss: 0.0974 - val_accuracy: 1.0000 - 44ms/epoch - 15ms/step
# Epoch 146/200
# 3/3 - 0s - loss: 0.1764 - accuracy: 0.9333 - val_loss: 0.1142 - val_accuracy: 0.9667 - 48ms/epoch - 16ms/step
# Epoch 147/200
# 3/3 - 0s - loss: 0.2480 - accuracy: 0.9556 - val_loss: 0.2130 - val_accuracy: 0.9000 - 48ms/epoch - 16ms/step
# Epoch 148/200
# 3/3 - 0s - loss: 0.1212 - accuracy: 0.9667 - val_loss: 0.1734 - val_accuracy: 0.9000 - 48ms/epoch - 16ms/step
# Epoch 149/200
# 3/3 - 0s - loss: 0.2012 - accuracy: 0.9556 - val_loss: 0.1119 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 150/200
# 3/3 - 0s - loss: 0.1513 - accuracy: 0.9444 - val_loss: 0.0872 - val_accuracy: 0.9667 - 46ms/epoch - 15ms/step
# Epoch 151/200
# 3/3 - 0s - loss: 0.1665 - accuracy: 0.9444 - val_loss: 0.0764 - val_accuracy: 1.0000 - 51ms/epoch - 17ms/step
# Epoch 152/200
# 3/3 - 0s - loss: 0.1749 - accuracy: 0.9556 - val_loss: 0.0827 - val_accuracy: 0.9667 - 66ms/epoch - 22ms/step
# Epoch 153/200
# 3/3 - 0s - loss: 0.2027 - accuracy: 0.9444 - val_loss: 0.1275 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 154/200
# 3/3 - 0s - loss: 0.1021 - accuracy: 0.9667 - val_loss: 0.1932 - val_accuracy: 0.9000 - 65ms/epoch - 22ms/step
# Epoch 155/200
# 3/3 - 0s - loss: 0.1711 - accuracy: 0.9333 - val_loss: 0.1135 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 156/200
# 3/3 - 0s - loss: 0.1214 - accuracy: 0.9667 - val_loss: 0.0692 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 157/200
# 3/3 - 0s - loss: 0.2195 - accuracy: 0.9222 - val_loss: 0.0665 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 158/200
# 3/3 - 0s - loss: 0.1849 - accuracy: 0.9556 - val_loss: 0.0751 - val_accuracy: 0.9667 - 46ms/epoch - 15ms/step
# Epoch 159/200
# 3/3 - 0s - loss: 0.1769 - accuracy: 0.9667 - val_loss: 0.0808 - val_accuracy: 0.9667 - 48ms/epoch - 16ms/step
# Epoch 160/200
# 3/3 - 0s - loss: 0.1305 - accuracy: 0.9556 - val_loss: 0.0868 - val_accuracy: 0.9667 - 48ms/epoch - 16ms/step
# Epoch 161/200
# 3/3 - 0s - loss: 0.1933 - accuracy: 0.9667 - val_loss: 0.1079 - val_accuracy: 0.9667 - 48ms/epoch - 16ms/step
# Epoch 162/200
# 3/3 - 0s - loss: 0.1827 - accuracy: 0.9444 - val_loss: 0.0927 - val_accuracy: 0.9667 - 47ms/epoch - 16ms/step
# Epoch 163/200
# 3/3 - 0s - loss: 0.0904 - accuracy: 0.9889 - val_loss: 0.0627 - val_accuracy: 0.9667 - 46ms/epoch - 15ms/step
# Epoch 164/200
# 3/3 - 0s - loss: 0.1404 - accuracy: 0.9556 - val_loss: 0.0535 - val_accuracy: 1.0000 - 46ms/epoch - 15ms/step
# Epoch 165/200
# 3/3 - 0s - loss: 0.1110 - accuracy: 0.9778 - val_loss: 0.0856 - val_accuracy: 0.9667 - 42ms/epoch - 14ms/step
# Epoch 166/200
# 3/3 - 0s - loss: 0.1667 - accuracy: 0.9667 - val_loss: 0.1291 - val_accuracy: 0.9667 - 46ms/epoch - 15ms/step
# Epoch 167/200
# 3/3 - 0s - loss: 0.1587 - accuracy: 0.9444 - val_loss: 0.1299 - val_accuracy: 0.9667 - 46ms/epoch - 15ms/step
# Epoch 168/200
# 3/3 - 0s - loss: 0.1745 - accuracy: 0.9333 - val_loss: 0.1089 - val_accuracy: 0.9667 - 47ms/epoch - 16ms/step
# Epoch 169/200
# 3/3 - 0s - loss: 0.1052 - accuracy: 0.9889 - val_loss: 0.0950 - val_accuracy: 0.9667 - 49ms/epoch - 16ms/step
# Epoch 170/200
# 3/3 - 0s - loss: 0.1470 - accuracy: 0.9556 - val_loss: 0.0629 - val_accuracy: 0.9667 - 47ms/epoch - 16ms/step
# Epoch 171/200
# 3/3 - 0s - loss: 0.1018 - accuracy: 0.9667 - val_loss: 0.0526 - val_accuracy: 0.9667 - 46ms/epoch - 15ms/step
# Epoch 172/200
# 3/3 - 0s - loss: 0.1296 - accuracy: 0.9556 - val_loss: 0.0856 - val_accuracy: 0.9667 - 46ms/epoch - 15ms/step
# Epoch 173/200
# 3/3 - 0s - loss: 0.1308 - accuracy: 0.9556 - val_loss: 0.1317 - val_accuracy: 0.9667 - 48ms/epoch - 16ms/step
# Epoch 174/200
# 3/3 - 0s - loss: 0.0560 - accuracy: 0.9889 - val_loss: 0.1514 - val_accuracy: 0.9333 - 43ms/epoch - 14ms/step
# Epoch 175/200
# 3/3 - 0s - loss: 0.1230 - accuracy: 0.9778 - val_loss: 0.1115 - val_accuracy: 0.9667 - 46ms/epoch - 15ms/step
# Epoch 176/200
# 3/3 - 0s - loss: 0.0771 - accuracy: 0.9778 - val_loss: 0.0774 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 177/200
# 3/3 - 0s - loss: 0.0895 - accuracy: 0.9778 - val_loss: 0.0711 - val_accuracy: 0.9667 - 47ms/epoch - 16ms/step
# Epoch 178/200
# 3/3 - 0s - loss: 0.1405 - accuracy: 0.9667 - val_loss: 0.0738 - val_accuracy: 0.9667 - 52ms/epoch - 17ms/step
# Epoch 179/200
# 3/3 - 0s - loss: 0.0493 - accuracy: 0.9889 - val_loss: 0.0800 - val_accuracy: 0.9667 - 50ms/epoch - 17ms/step
# Epoch 180/200
# 3/3 - 0s - loss: 0.0943 - accuracy: 0.9667 - val_loss: 0.0921 - val_accuracy: 0.9667 - 47ms/epoch - 16ms/step
# Epoch 181/200
# 3/3 - 0s - loss: 0.0822 - accuracy: 0.9778 - val_loss: 0.1800 - val_accuracy: 0.9000 - 47ms/epoch - 16ms/step
# Epoch 182/200
# 3/3 - 0s - loss: 0.0814 - accuracy: 0.9778 - val_loss: 0.2862 - val_accuracy: 0.9000 - 51ms/epoch - 17ms/step
# Epoch 183/200
# 3/3 - 0s - loss: 0.1477 - accuracy: 0.9444 - val_loss: 0.2965 - val_accuracy: 0.9000 - 68ms/epoch - 23ms/step
# Epoch 184/200
# 3/3 - 0s - loss: 0.1230 - accuracy: 0.9556 - val_loss: 0.1991 - val_accuracy: 0.9000 - 44ms/epoch - 15ms/step
# Epoch 185/200
# 3/3 - 0s - loss: 0.1115 - accuracy: 0.9556 - val_loss: 0.0655 - val_accuracy: 0.9667 - 43ms/epoch - 14ms/step
# Epoch 186/200
# 3/3 - 0s - loss: 0.0751 - accuracy: 0.9778 - val_loss: 0.0528 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 187/200
# 3/3 - 0s - loss: 0.2005 - accuracy: 0.9778 - val_loss: 0.0553 - val_accuracy: 0.9667 - 49ms/epoch - 16ms/step
# Epoch 188/200
# 3/3 - 0s - loss: 0.1276 - accuracy: 0.9667 - val_loss: 0.0575 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 189/200
# 3/3 - 0s - loss: 0.0940 - accuracy: 0.9556 - val_loss: 0.0693 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 190/200
# 3/3 - 0s - loss: 0.0582 - accuracy: 0.9889 - val_loss: 0.1135 - val_accuracy: 0.9667 - 44ms/epoch - 15ms/step
# Epoch 191/200
# 3/3 - 0s - loss: 0.0680 - accuracy: 0.9778 - val_loss: 0.1392 - val_accuracy: 0.9333 - 48ms/epoch - 16ms/step
# Epoch 192/200
# 3/3 - 0s - loss: 0.1166 - accuracy: 0.9778 - val_loss: 0.1671 - val_accuracy: 0.9000 - 49ms/epoch - 16ms/step
# Epoch 193/200
# 3/3 - 0s - loss: 0.1458 - accuracy: 0.9444 - val_loss: 0.1257 - val_accuracy: 0.9333 - 63ms/epoch - 21ms/step
# Epoch 194/200
# 3/3 - 0s - loss: 0.0900 - accuracy: 0.9556 - val_loss: 0.0759 - val_accuracy: 0.9667 - 47ms/epoch - 16ms/step
# Epoch 195/200
# 3/3 - 0s - loss: 0.0879 - accuracy: 0.9778 - val_loss: 0.0630 - val_accuracy: 0.9667 - 45ms/epoch - 15ms/step
# Epoch 196/200
# 3/3 - 0s - loss: 0.0973 - accuracy: 0.9778 - val_loss: 0.0597 - val_accuracy: 0.9667 - 48ms/epoch - 16ms/step
# Epoch 197/200
# 3/3 - 0s - loss: 0.0733 - accuracy: 0.9889 - val_loss: 0.0564 - val_accuracy: 0.9667 - 47ms/epoch - 16ms/step
# Epoch 198/200
# 3/3 - 0s - loss: 0.0734 - accuracy: 0.9778 - val_loss: 0.0617 - val_accuracy: 0.9667 - 49ms/epoch - 16ms/step
# Epoch 199/200
# 3/3 - 0s - loss: 0.0987 - accuracy: 0.9778 - val_loss: 0.0924 - val_accuracy: 0.9667 - 46ms/epoch - 15ms/step
# Epoch 200/200
# 3/3 - 0s - loss: 0.0508 - accuracy: 0.9889 - val_loss: 0.1059 - val_accuracy: 0.9667 - 48ms/epoch - 16ms/step

# %% [markdown]
# ### Plot the learning curves

# %%
plot_metric(history, 'loss')

# %% [markdown]
# Here, you can see that the overfitting is not completely fixed, but there is a signficant improvement when we compare it to the unregularized model

# %%
# Evaluate the model on the test set
model.evaluate(X_test, y_test, verbose=2)
# Out:
# 1/1 - 0s - loss: 0.1130 - accuracy: 0.9333 - 25ms/epoch - 25ms/step
# [0.11299627274274826, 0.9333333373069763]
